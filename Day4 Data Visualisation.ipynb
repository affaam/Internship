# %% [markdown]
# #### Date: 16/04/2024 Day: Tuesday
# #### Programmer: Affaan Attar
# #### College: Keystone School Of Engineering
# #### Class: TE-B(Computer)
# #### Roll No.: 50

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
x = np.array ([12,23,34,45,49,56,61,68,71,78])

y = np.array ([23,31,38,43,49,56,65,71,79,85])

z = np.array ([98,89,86,76,71,68,61,54,49,34])

# %% [markdown]
# LINE PLOT

# %%
plt.plot(x, y);

# %%
plt.plot(x, z);

# %%
plt.title('Line Plot')
plt.xlabel('First Value')
plt.ylabel('Second Value')
plt.plot(x, y, marker = 'o', color = 'blue', mfc = 'r');

# %%
plt.title('Line Plot')
plt.xlabel('First Value')
plt.ylabel('Second Value')
plt.plot(x, y, marker = 'o', color = 'blue', mfc = 'r', ls = '--', ms = 7);

# %%
plt.title('Line Plot')
plt.xlabel('First Value')
plt.ylabel('Second Value')
plt.plot(x, y, marker = 'o', color = 'blue', mfc = 'red', ls = '--', ms = 7);
plt.grid()
# marker => <,>,^,o,*,H

# %%
plt.title('Line Plot')
plt.xlabel('First Value')
plt.ylabel('Second Value')
plt.plot(x, z, marker = '*', color = 'cyan', mfc = 'blue', ls = '--', ms = 7);
plt.grid()
# marker => <,>,^,o,*,H

# %%
plt.title('Line Plot')
plt.xlabel('First Value')
plt.ylabel('Second Value')
plt.plot(x, y, marker = 'o', color = 'blue', mfc = 'r', ls = '--', ms = 7);
plt.plot(x, z, marker = '*', color = 'orange', mfc = 'blue', ls = '--', ms = 7);
plt.grid()

# %% [markdown]
# SUBPLOT

# %%
plt.subplot(2,2,1)
plt.title('Line Plot')
plt.xlabel('First Value')
plt.ylabel('Second Value')
plt.plot(x, y, marker = 'o', color = 'blue', mfc = 'red', ls = '--', ms = 7);
plt.grid()

plt.subplot(2,2,2)
plt.title('Line Plot')
plt.xlabel('First Value')
plt.ylabel('Second Value')
plt.plot(x, z, marker = '*', color = 'cyan', mfc = 'blue', ls = '--', ms = 7);
plt.grid()

# %% [markdown]
# BAR GRAPH

# %%
students = [56, 65, 46, 51, 61]

courses = ['Java', 'Python', 'R', 'Kotlin', 'Dart']

# %%
plt.bar(courses, students)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.title('Bar Plot')
plt.xlabel('Courses')
plt.ylabel('No. Of Students')
plt.bar(courses, students, color = 'cyan', edgecolor = 'red', width = 0.6, linewidth = 3);

# %%
plt.title('Bar Plot')
plt.xlabel('Courses')
plt.ylabel('No. Of Students')
plt.bar(courses, students, color = 'cyan', edgecolor = 'red', width = 0.6, linewidth = 3, alpha = 0.7);

# %% [markdown]
# SCATTER PLOT

# %%
plt.scatter(x, y, marker = '*')
plt.grid()

# %% [markdown]
# PIE CHART

# %%
plt.title('Pie Chart')
plt.pie(students, labels = courses);

# %%
plt.title('Pie Chart')
plt.pie(students, labels = courses, autopct = '%.2f%%', shadow = True);

# %%
plt.title('Pie Chart')
plt.pie(students, labels = courses, autopct = '%.3f%%');

# %%
plt.title('Pie Chart')
plt.pie(students, labels = courses, autopct = '%.3f%%', radius = 1.0);

# %%
plt.title('Pie Chart')
plt.pie(students, labels = courses, autopct = '%.3f%%', radius = 0.8, labeldistance = 1.2);

# %%
colors = ['orange', 'cyan', 'violet', 'red', 'blue']
plt.title('Pie Chart')
plt.pie(students, labels = courses, autopct = '%.3f%%', radius = 0.8, labeldistance = 1.2, colors = colors);

# %%
colors = ['orange', 'cyan', 'violet', 'red', 'blue']
plt.title('Pie Chart')
plt.pie(students, labels = courses, autopct = '%.3f%%', radius = 0.8, labeldistance = 1.2, colors = colors, startangle = 30);

# %%
colors = ['orange', 'cyan', 'violet', 'skyblue', 'blue']
plt.title('Pie Chart')
plt.pie(students, labels = courses, autopct = '%.3f%%', radius = 0.8, labeldistance = 1.2, colors = colors, startangle = 30, explode = [0,0,0.2,0,0]);

# %% [markdown]
# PLOTTING ALL TYPES IN A SINGLE FRAME

# %%
plt.figure(figsize=(15,15))

plt.subplot(4,4,1)
plt.title('Line Plot')
plt.xlabel('First Value')
plt.ylabel('Second Value')
plt.plot(x, y, marker = 'o', color = 'blue', mfc = 'red', ls = '--', ms = 7);
plt.grid()

plt.subplot(4,4,2)
plt.title('Line Plot')
plt.xlabel('First Value')
plt.ylabel('Second Value')
plt.plot(x, z, marker = '*', color = 'cyan', mfc = 'blue', ls = '--', ms = 7);
plt.grid()

plt.subplot(4,4,3)
plt.title('Pie Chart')
plt.pie(students, labels = courses, autopct = '%.3f%%', radius = 1.0, labeldistance = 1.2);

plt.subplot(4,4,4)
colors = ['orange', 'cyan', 'violet', 'red', 'blue']
plt.title('Pie Chart')
plt.pie(students, labels = courses, autopct = '%.3f%%', radius = 1.0, labeldistance = 1.2, colors = colors);

plt.subplot(4,4,7)
colors = ['orange', 'cyan', 'violet', 'skyblue', 'blue']
plt.title('Pie Chart')
plt.pie(students, labels = courses, autopct = '%.3f%%', radius = 1.0, labeldistance = 1.2, colors = colors, startangle = 30, explode = [0,0,0.2,0,0]);

plt.subplot(4,4,5)
plt.title('Bar Plot')
plt.xlabel('Courses')
plt.ylabel('No. Of Students')
plt.bar(courses, students, color = 'cyan', edgecolor = 'red', width = 0.6, linewidth = 3);

plt.subplot(4,4,6)
plt.scatter(x, y, marker = '*')
plt.grid()

plt.subplot(4,4,8)
plt.title('Line Plot')
plt.xlabel('First Value')
plt.ylabel('Second Value')
plt.plot(x, y, marker = 'o', color = 'blue', mfc = 'r', ls = '--', ms = 7);
plt.plot(x, z, marker = '*', color = 'orange', mfc = 'blue', ls = '--', ms = 7);
plt.grid()

plt.subplot(4,4,9)
colors = '#071125'
plt.xlabel('student')
plt.ylabel('marks')
plt.bar(df['name'],df['marks'], color = colors, edgecolor = 'red', linewidth = 3);

plt.subplots_adjust(wspace=0.5)
plt.subplots_adjust(hspace=0.5)

plt.show()

# %% [markdown]
# BOXPLOT

# %%
marks = [67, 63, 70, 71, 72, 56, 51, 21, 95]

# %%
plt.boxplot(marks);

# %%
q3 = np.percentile(marks,75)
q1 = np.percentile(marks,75)

# %%
q3,q1
# Out:
# (71.0, 71.0)

# %%
iqr = q3 - q1
iqr
# Out:
# 0.0

# %%
lb = q1 - 1.5 + iqr

# %%
lb
# Out:
# 69.5

# %%
ub = q3 + 1.5 + iqr

# %%
ub
# Out:
# 72.5

# %%
df = pd.read_csv('student.csv')

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
colors = '#071125'
plt.xlabel('student')
plt.ylabel('marks')
plt.bar(df['name'],df['marks'], color = colors, edgecolor = 'red', linewidth = 3);

# %% [markdown]
# SEABORN

# %%
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)
sns.jointplot(x = 'tip', y = 'total_bill', data = tips, hue = 'time')
plt.show()

# %% [markdown]
# HISTOGRAM

# %%
plt.xlabel('Tip Amount')
plt.ylabel('Frequency')
sns.histplot(tips['tip'], kde = True)
plt.show()

# %%
df = sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.pairplot(df, hue = 'alive')
plt.show()

# %%
sns.boxplot(x = 'sex', y = 'age', hue = 'survived', data = df)
plt.title('Distribution Of Age wrt Gender(Survived vs Not Survived)')
plt.xlabel('Gender')
plt.ylabel('Age')
plt.show()
